# %%
import numpy as np
from scipy.integrate import odeint, solve_ivp
import matplotlib.pyplot as plt

# %%
#DEFINIMOS UNA FUNCION PARA APLICAR EL METODO DE EULER PARA RESOLVER EDO
 #   '''Aproxima la solución de y'=f(y,t) por el método de Euler.
  #  Parámetros: f : La función dada por el lado derecho de la ecuación diferencial y'=f(t,y), y(t_0)=y_0
  #  y0 : El valor inicial de y al tiempo y(t0)=y0 
   # t : Arreglo unidimensional de 1D. El tamaño del paso h = t[n+1] - t[n].
def MEuler(f,y0,t):
     #creamos un arreglo del tamaño de t, es decir del numero de iteraciones que se realizaran
      y = np.zeros(len(t))
      y[0] = y0
      for n in range(0,len(t)-1):
        y[n+1] = y[n] + f(y[n],t[n])*(t[n+1] - t[n])
      return y

# %% [markdown]
# Ejercicio 1:
#
# Resuelva la ecuación diferencial del oscilador de Van der Pol
#
# $$\begin{equation*}
# \frac{d^2 x}{d t^2} - \mu (1 - x^2) \frac{dx}{dt } + x = 0
# \end{equation*}$$
# donde $x$ es la posición y $\mu$ es un parámetro de la parte no lineal.
#
# Resuelva el caso para $\mu = 0, 1, 2, 3, 4$ y grafique las soluciones para un tiempo de integración de t = [0, 50]

# %%
#Resolveremos el oscilador de Van der Pol para mu=0
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=0
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best")
plt.title("Oscilador de Van der Pol para mu=0")
plt.grid()
#vemos que es el caso de un oscilador armonico clasico

# %%
#Resolveremos el oscilador de Van der Pol para mu=1
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=1
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best" )
plt.title("Oscilador de Van der Pol para mu=1")
plt.grid()

# %%
#Resolveremos el oscilador de Van der Pol para mu=2
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=2
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best" )
plt.title("Oscilador de Van der Pol para mu=2")
plt.grid()

# %%
#Resolveremos el oscilador de Van der Pol para mu=3
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=3
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best") 
plt.title("Oscilador de Van der Pol para mu=3")
plt.grid()

# %%
#Resolveremos el oscilador de Van der Pol para mu=4
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=4
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best") 
plt.title("Oscilador de Van der Pol para mu=4")
plt.grid()

# %%
#Resolveremos el oscilador de Van der Pol para mu=5
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,50,500)
mu=5
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx=Sol[:,0]
Solv=Sol[:,1]
#print(Sol)
plt.figure(figsize=(20,10))
plt.plot(t,Solx,"lime",label="x")
plt.plot(t,Solv,"magenta", label="v")
plt.legend( loc = "best") 
plt.title("Oscilador de Van der Pol para mu=5")
plt.grid()

# %% [markdown]
# Ejercicio 2:
#
# Siguiendo con el ejemplo anterior del oscilador de Van de Pol, reproduce la gráfica del plano fase ($\theta, \omega$) que aparece en la Wikipedia para distintos valores de $\mu$ y se reproduce abajo.

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,6.5,500)
mu=0.01
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx1=Sol[:,0]
Solv1=Sol[:,1]
#plt.plot(Solx1,Solv1,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,7,500)
mu=0.1
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx2=Sol[:,0]
Solv2=Sol[:,1]
#plt.plot(Solx2,Solv2,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,6.5,500)
mu=0.5
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx3=Sol[:,0]
Solv3=Sol[:,1]
#plt.plot(Solx3,Solv3,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,7.8,500)
mu=1
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx4=Sol[:,0]
Solv4=Sol[:,1]
#plt.plot(Solx4,Solv4,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,10,500)
mu=1.5
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx5=Sol[:,0]
Solv5=Sol[:,1]
#plt.plot(Solx4,Solv4,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,10,500)
mu=2
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx6=Sol[:,0]
Solv6=Sol[:,1]
#plt.plot(Solx5,Solv5,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,10,500)
mu=2.5
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx7=Sol[:,0]
Solv7=Sol[:,1]
#plt.plot(Solx6,Solv6,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,15
              ,500)
mu=3
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx8=Sol[:,0]
Solv8=Sol[:,1]
#plt.plot(Solx7,Solv7,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,15,500)
mu=3.5
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx9=Sol[:,0]
Solv9=Sol[:,1]
#plt.plot(Solx8,Solv8,"silver")
#plt.show()

# %%
def oscilador(y,t,m):
  x,v=y
  dydt=[v,m*(1-x**2)*v-x]
  return dydt
#definimos constantes y condiciones iniciales y el tiempo de integracion
t=np.linspace(0,15,500)
mu=4
#ponemos como posicion inicial x=1, para que comienze la oscilacion, si x=0 el oscilador se mantiene en reposo en el origen
y0=[1,0]
#resolvemos con la funcion de odeint
Sol = odeint( oscilador, y0, t, args=(mu,) ) 
Solx10=Sol[:,0]
Solv10=Sol[:,1]
#plt.plot(Solx9,Solv9,"silver")
#plt.show()

# %%
plt.figure(figsize=(5,14))
plt.plot(Solx1,Solv1,"lightgray", label=("mu=0.01"))
plt.plot(Solx2,Solv2,"lightgray", label=("mu=0.1"))
plt.plot(Solx3,Solv3,"lightgray", label=("mu=0.5"))
plt.plot(Solx4,Solv4,"lightgray", label=("mu=1"))
plt.plot(Solx5,Solv5,"lightgray", label=("mu=1.5"))
plt.plot(Solx6,Solv6,"lightgray", label=("mu=2"))
plt.plot(Solx7,Solv7,"lightgray", label=("mu=2.5"))
plt.plot(Solx8,Solv8,"lightgray", label=("mu=3"))
plt.plot(Solx9,Solv9,"lightgray", label=("mu=3.5"))
plt.plot(Solx10,Solv10,"lightgray", label=("mu=4"))
plt.title("Plano fase (x,v) del oscilador de Van der Pol con diferentes parametros")
plt.show()

# %% [markdown]
# Ejercicios 3:
#
# Encuentre las soluciones de las siguientes Ecuaciones Diferenciales Ordinarias, utilizando los siguientes métodos:
#
# Método de Euler
# Método de Runge-Kutta RK4
# Función scipy.integrate.odeint ó scipy.integrate-solve_ivp
#
# Ejercicio 3.1:
# $$\begin{equation*}
# \frac{d^2 x}{dt^2} + k (\frac{dx}{dt})^2 -g = 0, \ x(0)=0, \ \frac{dx}{dt}(0). = 0, \ k>0.
# \end{equation*}$$
# Ejercicio 3.2:
#
# $$\begin{equation*}
# \frac{d^2 y}{d x^2} + \frac{2}{x} \frac{dy}{dx} + y^5 =0, \ y(0) = 1, \ \frac{dy}{dx}(0)=0.
# \end{equation*}$$
# Ejercicio 3.3:
#
# $$\begin{equation*}
# \frac{d^3 y}{d x^3} = (x-1)^2 + y^2 + \frac{dy}{dx} -2, \ y(0)=1, \ y'(0)=0, \ y''(0)=2.
# \end{equation*}$$
# Grafique las soluciones como funciones del tiempo.

# %%
#RESOLVEMOS EL EJERCICIO 3.1 CON EL METODO DE EULER
#resolvemos para v=dx/dt
t=np.linspace(0,5,51)
k=1
g=9.8
f = lambda v,t: -k*v**2 + g 
v = np.zeros( len( t ) )
v[ 0 ] = 0
for n in range( 0, len( t ) - 1 ):
  v[ n+1 ] = v[ n ] + f (v[ n ], t[ n ] )*( t[ n+1 ] - t[ n ] )
#resolvemos para x
x = np.zeros( len(t) )
x[ 0 ] = 0
for n in range(0,len(t)-1):
  x[ n+1 ] = x[ n ] + v[ n ]*( t[ n+1 ] - t[ n ] )

plt.figure( figsize = ( 20, 10 ) )
plt.plot( t, v, "lime", t, x, "magenta" )
plt.legend( [ "v" ,"x" ] )
plt.title( "Solución de la ecuación diferencial con el metodo de Euler" )

plt.grid()

# %%
#RESOLVEMOS EL EJERCICIO 3.1 USANDO EL METODO RK4 
# Tomada la versión de Joshua Simon
# https://github.com/JoshuaSimon/Classic-Fourth-Order-Runge-Kutta-Method-RK4/blob/master/Four_Step_Runge_Kutta_ODE1.py

"""Four_Step_Runge_Kutta_ODE1.py 

Implementation of the classic fourth-order method also refered as the
"original" Runge–Kutta method. This method is an implicit four step
Runge-Kutta method which solves an intial value problem numerically. 
"""

from datetime import datetime
import matplotlib.pyplot as plt
from math import exp, sqrt 

__date__ = datetime(2019, 6, 6) # or version string or something
__author__ = "Joshua Simon"


def runge_kutta(f, x_0, y_0, h):
    """Four step Runge-Kutta method (RK4)
    Solves first order ODEs
    """
    k_0 = f(x_0, y_0)
    k_1 = f(x_0 + h/2, y_0 + h/2 * k_0)
    k_2 = f(x_0 + h/2, y_0 + h/2 * k_1)
    k_3 = f(x_0 + h, y_0 + h * k_2)

    k = 1/6 * (k_0 + 2.0*k_1 + 2.0*k_2 + k_3)

    x_1 = x_0 + h
    y_1 = y_0 + h * k

    return x_1, y_1

# %%
#RESOLVEMOS EL EJERCICIO 3.1 USANDO EL METODO RK4 
#DEFINIMOS LOS PARAMETROS Y CONDICIONES INICIALES
a = 0
b = 5.0 
Npts = 50
h = (b-a)/Npts
t0 = 0
x0 = 0
v0 = 0
k = 1
g = 9.81
t=0
v=0
#DEFINIMOS LA PRIMERA ECUACION
f = lambda t,v: -k*v**2 + g 
t_values = [t0]
v_values = [v0]
# IMPLEMENTANDO RUNGE KUTTA 4
for _ in range(Npts):
  t, v = runge_kutta(f, t, v, h)
  t_values.append(t)
  v_values.append(v)

#NO ES POSIBLE ENCONTRAR UNA ECUACION DX/DT EN TERMINOS DE X Y T, POR ESO NO ES POSIBLE IMPLEMENTAR RK4, ASI QUE USAREMOS SOLVE_IVP
# DEFINIMOS LA FUNCION A  INTEGRAR
def FUNCION(t,y,k,g):
      dydt = [y[1], -k*(y[1])**2 + g]
      return dydt
t0=0
tmax=5
Npts=50
t_0 = 0.0
y_0 = [x0, v0]
#DEFINIMOS LOS PUNTOS DONDE INTEGRAREMOS
t = np.linspace(t0,tmax,Npts)
abserr = 1.0e-8
relerr = 1.0e-6
sol = solve_ivp(lambda t, y, mu: FUNCION(t, y, k, g),(t0,tmax), y0=y_0, 
                method='RK45', t_eval=t, args=(mu,), rtol=relerr, atol=abserr)
x=sol.y[0]
plt.figure(figsize=(20,10))
plt.plot(t_values,v_values,'lime', label='v(t)')
plt.plot(t,x,'magenta', label='x(t)')
plt.legend(loc='best')
plt.grid()
plt.title("Solución de la ecuacion diferencial mediante RK4")
plt.xlabel('t')
plt.show()

# %%
def ED1( y, t, k, g ):
        x, v = y
        dydt = [v, g - k*v**2 ]
        return dydt
t = np.linspace(0, 5, 51)
t0 = 0
x0 = 0
v0 = 0

k = 1
g = 9.81

# %%
#RESOLVEMOS USANDO EL METODO ODEINT 
t0=0
tmax= 5.0
Npts=51
t = np.linspace(t0,tmax,Npts)
#DEFINIMOS LOS PARAMETROS INICIALES 
x_0 = 0.0
a_0 = [1.0, 0.0]
sol=odeint(ED1, a_0, t, args=(k,g))
#DEFINIMOS X Y V
X=sol[:,0]
V=sol[:,1]

plt.figure(figsize=(20,10))
plt.plot(t, X, 'lime', label='x(t)')
plt.plot(t, V, 'magenta', label='v(t)')
plt.legend(loc='best')
plt.title('Solución de la ecuacion diferencial mediante instruccion odeint')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
# EJERCICIO 3.2 
# NO ES POSIBLE APLICAR EL METODO DE EULER Y DE RK4 DEBIDO A LAS VARIABLES QUE APARECEN EN LAS ECUACIONES QUE SE PLANTEA PARA SU SOLUCION
# USANDO LA INSTRUCCION ODEINT
# DEFINIMOS  
def fun(a, x):
        y, v = a
        dadx = [v, -(2/x)*v -y**5]
        return dadx
#DEFINIMOS LOS PARAMETROS INICIALES
x0 = 0.1
y0 = 1.0
v0 = 0
x = np.linspace(0.1, 10, 100)
x_0 = x0
a_0 = [y0, v0]
Sol=odeint(fun, a_0, x)
X=Sol[:,0]
V=Sol[:,1]
plt.figure(figsize=(20,10))
plt.plot(x, X, 'lime', label='x(t)')
plt.plot(x, V, 'magenta', label='v(t)')
plt.legend(loc='best')
plt.title('Solución de la ecuacion diferencial mediante instruccion odeint')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
#EJERCICIO 3.3
#AL IGUAL QUE EN EL EJERCICIO ANTERIOR SOLO ES POSIBLE RESOLVER ESTA ED MEDIANTE ODEINT
def f1(b, x):
        y, v, a = b
        dbdx = [v, a, (x-1)**2 + y**2 + v - 2]
        return dbdx

x0 = 0.0
y0 = 1.0
v0 = 0.0
a0 = 2.0
x = np.linspace(0.0, 2.5, 50)

#DEFINIMOS PARAMETROS INICLAES Y RESOLVEMOS LA ED 
x_0 = x0
a_0 = [y0, v0, a0]

sol=odeint(f1, a_0, x)

X=sol[:,0]
V=sol[:,1]
A=sol[:,2]

plt.figure(figsize=(20,10))
plt.plot(x, X, 'g.-', label='x(t)')
plt.plot(x, V, 'm.-', label='v(t)')
plt.plot(x, A, 'c.-', label='a(t)')
plt.legend(loc='best')
plt.title('Solución mediante la instruccion odeint')
plt.xlabel('t')
plt.grid()
plt.show()
